# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import optimizers
import numpy as np
from keras.layers.core import Lambda
from keras import backend as K
from keras import regularizers

loss_holder = []
accuracy_holder = []
val_loss_holder = []
val_accuracy_holder = []

class cifar10vgg:
    def __init__(self,train=True):
        self.num_classes = 10
        self.weight_decay = 0.0005
        self.x_shape = [32,32,3]

        self.model = self.build_model()
        if train:
            self.model = self.train(self.model)
        else:
            self.model.load_weights('cifar10vgg.h5')


    def build_model(self):
        # Build the network of vgg for 10 classes with massive dropout and weight decay as described in the paper.

        model = Sequential()
        weight_decay = self.weight_decay

        model.add(Conv2D(64, (3, 3), padding='same',
                         input_shape=self.x_shape,kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))

        model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))


        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))


        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.5))

        model.add(Flatten())
        model.add(Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Dropout(0.5))
        model.add(Dense(self.num_classes))
        model.add(Activation('softmax'))
        return model


    def normalize(self,X_train,X_test):
        #this function normalize inputs for zero mean and unit variance
        # it is used when training a model.
        # Input: training set and test set
        # Output: normalized training set and test set according to the trianing set statistics.
        mean = np.mean(X_train,axis=(0,1,2,3))
        std = np.std(X_train, axis=(0, 1, 2, 3))
        X_train = (X_train-mean)/(std+1e-7)
        X_test = (X_test-mean)/(std+1e-7)
        return X_train, X_test

    def normalize_production(self,x):
        #this function is used to normalize instances in production according to saved training set statistics
        # Input: X - a training set
        # Output X - a normalized training set according to normalization constants.

        #these values produced during first training and are general for the standard cifar10 training set normalization
        mean = 120.707
        std = 64.15
        return (x-mean)/(std+1e-7)

    def predict(self,x,normalize=True,batch_size=50):
        if normalize:
            x = self.normalize_production(x)
        return self.model.predict(x,batch_size)

    def train(self,model):

        #training parameters
        batch_size = 128
        maxepoches = 250
        learning_rate = 0.1
        lr_decay = 1e-6
        lr_drop = 20
        # The data, shuffled and split between train and test sets:
        (x_train, y_train), (x_test, y_test) = cifar10.load_data()
        x_train = x_train.astype('float32')
        x_test = x_test.astype('float32')
        x_train, x_test = self.normalize(x_train, x_test)

        y_train = keras.utils.to_categorical(y_train, self.num_classes)
        y_test = keras.utils.to_categorical(y_test, self.num_classes)

        def lr_scheduler(epoch):
            return learning_rate * (0.5 ** (epoch // lr_drop))
        reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)

        #data augmentation
        datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
            width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
            height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False)  # randomly flip images
        # (std, mean, and principal components if ZCA whitening is applied).
        datagen.fit(x_train)



        #optimization details
        sgd = optimizers.SGD(lr=learning_rate, decay=lr_decay, momentum=0.9, nesterov=True)
        model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])


        # training process in a for loop with learning rate drop every 25 epoches.

        historytemp = model.fit_generator(datagen.flow(x_train, y_train,
                                         batch_size=batch_size),
                            steps_per_epoch=x_train.shape[0] // batch_size,
                            epochs=maxepoches,
                            validation_data=(x_test, y_test),callbacks=[reduce_lr],verbose=2)
        model.save_weights('cifar10vgg.h5')
        return model

if __name__ == '__main__':


    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')

    y_train = keras.utils.to_categorical(y_train, 10)
    y_test = keras.utils.to_categorical(y_test, 10)

    model = cifar10vgg()

    predicted_x = model.predict(x_test)
    residuals = np.argmax(predicted_x,1)!=np.argmax(y_test,1)

    loss = sum(residuals)/len(residuals)
    print("the validation 0/1 loss is: ",loss)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# WARNING:tensorflow:From <ipython-input-1-33aa108c1d68>:198: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/250
# 390/390 - 28s - loss: 20.0963 - accuracy: 0.1617 - val_loss: 14.3573 - val_accuracy: 0.1813
# Epoch 2/250
# 390/390 - 27s - loss: 10.3928 - accuracy: 0.2738 - val_loss: 7.8284 - val_accuracy: 0.1707
# Epoch 3/250
# 390/390 - 27s - loss: 5.6465 - accuracy: 0.3613 - val_loss: 4.7266 - val_accuracy: 0.2318
# Epoch 4/250
# 390/390 - 27s - loss: 3.4616 - accuracy: 0.4425 - val_loss: 2.9960 - val_accuracy: 0.3783
# Epoch 5/250
# 390/390 - 27s - loss: 2.3947 - accuracy: 0.5223 - val_loss: 2.1940 - val_accuracy: 0.5104
# Epoch 6/250
# 390/390 - 27s - loss: 1.8878 - accuracy: 0.5815 - val_loss: 1.9060 - val_accuracy: 0.5844
# Epoch 7/250
# 390/390 - 27s - loss: 1.6478 - accuracy: 0.6284 - val_loss: 1.5109 - val_accuracy: 0.6794
# Epoch 8/250
# 390/390 - 27s - loss: 1.5473 - accuracy: 0.6585 - val_loss: 1.4367 - val_accuracy: 0.6964
# Epoch 9/250
# 390/390 - 27s - loss: 1.5002 - accuracy: 0.6772 - val_loss: 1.6362 - val_accuracy: 0.6583
# Epoch 10/250
# 390/390 - 27s - loss: 1.4860 - accuracy: 0.6919 - val_loss: 1.4043 - val_accuracy: 0.7225
# Epoch 11/250
# 390/390 - 27s - loss: 1.4701 - accuracy: 0.7055 - val_loss: 1.4690 - val_accuracy: 0.7084
# Epoch 12/250
# 390/390 - 27s - loss: 1.4564 - accuracy: 0.7104 - val_loss: 1.3545 - val_accuracy: 0.7508
# Epoch 13/250
# 390/390 - 26s - loss: 1.4539 - accuracy: 0.7207 - val_loss: 1.3651 - val_accuracy: 0.7518
# Epoch 14/250
# 390/390 - 27s - loss: 1.4553 - accuracy: 0.7239 - val_loss: 1.3938 - val_accuracy: 0.7536
# Epoch 15/250
# 390/390 - 26s - loss: 1.4772 - accuracy: 0.7243 - val_loss: 1.4181 - val_accuracy: 0.7512
# Epoch 16/250
# 390/390 - 27s - loss: 1.4906 - accuracy: 0.7291 - val_loss: 1.4785 - val_accuracy: 0.7311
# Epoch 17/250
# 390/390 - 27s - loss: 1.4838 - accuracy: 0.7344 - val_loss: 1.5716 - val_accuracy: 0.7089
# Epoch 18/250
# 390/390 - 26s - loss: 1.4930 - accuracy: 0.7373 - val_loss: 1.4130 - val_accuracy: 0.7583
# Epoch 19/250
# 390/390 - 26s - loss: 1.5039 - accuracy: 0.7356 - val_loss: 1.4757 - val_accuracy: 0.7495
# Epoch 20/250
# 390/390 - 26s - loss: 1.5142 - accuracy: 0.7386 - val_loss: 1.5412 - val_accuracy: 0.7396
# Epoch 21/250
# 390/390 - 26s - loss: 1.3299 - accuracy: 0.7808 - val_loss: 1.1948 - val_accuracy: 0.8069
# Epoch 22/250
# 390/390 - 26s - loss: 1.2264 - accuracy: 0.7890 - val_loss: 1.1358 - val_accuracy: 0.8155
# Epoch 23/250
# 390/390 - 26s - loss: 1.2037 - accuracy: 0.7890 - val_loss: 1.1858 - val_accuracy: 0.7914
# Epoch 24/250
# 390/390 - 26s - loss: 1.1920 - accuracy: 0.7905 - val_loss: 1.1467 - val_accuracy: 0.8113
# Epoch 25/250
# 390/390 - 26s - loss: 1.1855 - accuracy: 0.7914 - val_loss: 1.2049 - val_accuracy: 0.7924
# Epoch 26/250
# 390/390 - 27s - loss: 1.1996 - accuracy: 0.7927 - val_loss: 1.1440 - val_accuracy: 0.8123
# Epoch 27/250
# 390/390 - 26s - loss: 1.2001 - accuracy: 0.7952 - val_loss: 1.1866 - val_accuracy: 0.8010
# Epoch 28/250
# 390/390 - 26s - loss: 1.2016 - accuracy: 0.7956 - val_loss: 1.2243 - val_accuracy: 0.7876
# Epoch 29/250
# 390/390 - 27s - loss: 1.2015 - accuracy: 0.7986 - val_loss: 1.1285 - val_accuracy: 0.8117
# Epoch 30/250
# 390/390 - 26s - loss: 1.2063 - accuracy: 0.7986 - val_loss: 1.1249 - val_accuracy: 0.8263
# Epoch 31/250
# 390/390 - 27s - loss: 1.2064 - accuracy: 0.8008 - val_loss: 1.0990 - val_accuracy: 0.8359
# Epoch 32/250
# 390/390 - 27s - loss: 1.2114 - accuracy: 0.7997 - val_loss: 1.4242 - val_accuracy: 0.7426
# Epoch 33/250
# 390/390 - 26s - loss: 1.2157 - accuracy: 0.8004 - val_loss: 1.3049 - val_accuracy: 0.7824
# Epoch 34/250
# 390/390 - 26s - loss: 1.2118 - accuracy: 0.8022 - val_loss: 1.1145 - val_accuracy: 0.8322
# Epoch 35/250
# 390/390 - 26s - loss: 1.2247 - accuracy: 0.8032 - val_loss: 1.1029 - val_accuracy: 0.8456
# Epoch 36/250
# 390/390 - 26s - loss: 1.2175 - accuracy: 0.8037 - val_loss: 1.1955 - val_accuracy: 0.8147
# Epoch 37/250
# 390/390 - 26s - loss: 1.2110 - accuracy: 0.8053 - val_loss: 1.1576 - val_accuracy: 0.8278
# Epoch 38/250
# 390/390 - 26s - loss: 1.2186 - accuracy: 0.8061 - val_loss: 1.1629 - val_accuracy: 0.8288
# Epoch 39/250
# 390/390 - 27s - loss: 1.2207 - accuracy: 0.8056 - val_loss: 1.1893 - val_accuracy: 0.8146
# Epoch 40/250
# 390/390 - 26s - loss: 1.2232 - accuracy: 0.8061 - val_loss: 1.2459 - val_accuracy: 0.7995
# Epoch 41/250
# 390/390 - 27s - loss: 1.1023 - accuracy: 0.8377 - val_loss: 1.0329 - val_accuracy: 0.8483
# Epoch 42/250
# 390/390 - 26s - loss: 1.0256 - accuracy: 0.8486 - val_loss: 0.9850 - val_accuracy: 0.8494
# Epoch 43/250
# 390/390 - 26s - loss: 0.9935 - accuracy: 0.8476 - val_loss: 0.9540 - val_accuracy: 0.8544
# Epoch 44/250
# 390/390 - 26s - loss: 0.9719 - accuracy: 0.8476 - val_loss: 0.8827 - val_accuracy: 0.8729
# Epoch 45/250
# 390/390 - 26s - loss: 0.9582 - accuracy: 0.8478 - val_loss: 0.9145 - val_accuracy: 0.8599
# Epoch 46/250
# 390/390 - 26s - loss: 0.9611 - accuracy: 0.8449 - val_loss: 0.8787 - val_accuracy: 0.8642
# Epoch 47/250
# 390/390 - 26s - loss: 0.9561 - accuracy: 0.8479 - val_loss: 0.8994 - val_accuracy: 0.8606
# Epoch 48/250
# 390/390 - 26s - loss: 0.9574 - accuracy: 0.8448 - val_loss: 0.9313 - val_accuracy: 0.8564
# Epoch 49/250
# 390/390 - 27s - loss: 0.9495 - accuracy: 0.8494 - val_loss: 0.8927 - val_accuracy: 0.8656
# Epoch 50/250
# 390/390 - 26s - loss: 0.9554 - accuracy: 0.8479 - val_loss: 0.9533 - val_accuracy: 0.8518
# Epoch 51/250
# 390/390 - 26s - loss: 0.9575 - accuracy: 0.8487 - val_loss: 0.8927 - val_accuracy: 0.8671
# Epoch 52/250
# 390/390 - 26s - loss: 0.9541 - accuracy: 0.8480 - val_loss: 0.9187 - val_accuracy: 0.8620
# Epoch 53/250
# 390/390 - 26s - loss: 0.9543 - accuracy: 0.8485 - val_loss: 0.8909 - val_accuracy: 0.8731
# Epoch 54/250
# 390/390 - 26s - loss: 0.9537 - accuracy: 0.8501 - val_loss: 0.9053 - val_accuracy: 0.8612
# Epoch 55/250
# 390/390 - 26s - loss: 0.9553 - accuracy: 0.8517 - val_loss: 0.9503 - val_accuracy: 0.8546
# Epoch 56/250
# 390/390 - 26s - loss: 0.9538 - accuracy: 0.8526 - val_loss: 0.9308 - val_accuracy: 0.8654
# Epoch 57/250
# 390/390 - 27s - loss: 0.9603 - accuracy: 0.8505 - val_loss: 1.0333 - val_accuracy: 0.8323
# Epoch 58/250
# 390/390 - 26s - loss: 0.9563 - accuracy: 0.8521 - val_loss: 0.9087 - val_accuracy: 0.8607
# Epoch 59/250
# 390/390 - 26s - loss: 0.9494 - accuracy: 0.8543 - val_loss: 0.9451 - val_accuracy: 0.8573
# Epoch 60/250
# 390/390 - 27s - loss: 0.9551 - accuracy: 0.8531 - val_loss: 0.9114 - val_accuracy: 0.8676
# Epoch 61/250
# 390/390 - 27s - loss: 0.8713 - accuracy: 0.8764 - val_loss: 0.8037 - val_accuracy: 0.8938
# Epoch 62/250
# 390/390 - 27s - loss: 0.8248 - accuracy: 0.8860 - val_loss: 0.8220 - val_accuracy: 0.8818
# Epoch 63/250
# 390/390 - 26s - loss: 0.8034 - accuracy: 0.8876 - val_loss: 0.7646 - val_accuracy: 0.8971
# Epoch 64/250
# 390/390 - 26s - loss: 0.7783 - accuracy: 0.8891 - val_loss: 0.7773 - val_accuracy: 0.8855
# Epoch 65/250
# 390/390 - 27s - loss: 0.7679 - accuracy: 0.8902 - val_loss: 0.7533 - val_accuracy: 0.8951
# Epoch 66/250
# 390/390 - 26s - loss: 0.7618 - accuracy: 0.8888 - val_loss: 0.7808 - val_accuracy: 0.8799
# Epoch 67/250
# 390/390 - 26s - loss: 0.7513 - accuracy: 0.8906 - val_loss: 0.7590 - val_accuracy: 0.8854
# Epoch 68/250
# 390/390 - 26s - loss: 0.7485 - accuracy: 0.8879 - val_loss: 0.7719 - val_accuracy: 0.8850
# Epoch 69/250
# 390/390 - 26s - loss: 0.7533 - accuracy: 0.8852 - val_loss: 0.7410 - val_accuracy: 0.8917
# Epoch 70/250
# 390/390 - 26s - loss: 0.7432 - accuracy: 0.8885 - val_loss: 0.7552 - val_accuracy: 0.8850
# Epoch 71/250
# 390/390 - 26s - loss: 0.7416 - accuracy: 0.8890 - val_loss: 0.7469 - val_accuracy: 0.8841
# Epoch 72/250
# 390/390 - 27s - loss: 0.7340 - accuracy: 0.8903 - val_loss: 0.7296 - val_accuracy: 0.8922
# Epoch 73/250
# 390/390 - 27s - loss: 0.7409 - accuracy: 0.8871 - val_loss: 0.7440 - val_accuracy: 0.8921
# Epoch 74/250
# 390/390 - 26s - loss: 0.7424 - accuracy: 0.8871 - val_loss: 0.7475 - val_accuracy: 0.8873
# Epoch 75/250
# 390/390 - 27s - loss: 0.7358 - accuracy: 0.8903 - val_loss: 0.7646 - val_accuracy: 0.8836
# Epoch 76/250
# 390/390 - 27s - loss: 0.7370 - accuracy: 0.8896 - val_loss: 0.7287 - val_accuracy: 0.8900
# Epoch 77/250
# 390/390 - 27s - loss: 0.7342 - accuracy: 0.8901 - val_loss: 0.7541 - val_accuracy: 0.8830
# Epoch 78/250
# 390/390 - 27s - loss: 0.7394 - accuracy: 0.8888 - val_loss: 0.7203 - val_accuracy: 0.8967
# Epoch 79/250
# 390/390 - 27s - loss: 0.7444 - accuracy: 0.8871 - val_loss: 0.7512 - val_accuracy: 0.8899
# Epoch 80/250
# 390/390 - 26s - loss: 0.7422 - accuracy: 0.8869 - val_loss: 0.7330 - val_accuracy: 0.8924
# Epoch 81/250
# 390/390 - 26s - loss: 0.6810 - accuracy: 0.9062 - val_loss: 0.7089 - val_accuracy: 0.9014
# Epoch 82/250
# 390/390 - 26s - loss: 0.6481 - accuracy: 0.9150 - val_loss: 0.6804 - val_accuracy: 0.9073
# Epoch 83/250
# 390/390 - 26s - loss: 0.6318 - accuracy: 0.9169 - val_loss: 0.6478 - val_accuracy: 0.9131
# Epoch 84/250
# 390/390 - 27s - loss: 0.6228 - accuracy: 0.9163 - val_loss: 0.6467 - val_accuracy: 0.9116
# Epoch 85/250
# 390/390 - 26s - loss: 0.6169 - accuracy: 0.9172 - val_loss: 0.6508 - val_accuracy: 0.9096
# Epoch 86/250
# 390/390 - 26s - loss: 0.6007 - accuracy: 0.9200 - val_loss: 0.6245 - val_accuracy: 0.9141
# Epoch 87/250
# 390/390 - 26s - loss: 0.5916 - accuracy: 0.9215 - val_loss: 0.6245 - val_accuracy: 0.9176
# Epoch 88/250
# 390/390 - 26s - loss: 0.5892 - accuracy: 0.9190 - val_loss: 0.6229 - val_accuracy: 0.9120
# Epoch 89/250
# 390/390 - 26s - loss: 0.5862 - accuracy: 0.9195 - val_loss: 0.6307 - val_accuracy: 0.9097
# Epoch 90/250
# 390/390 - 26s - loss: 0.5773 - accuracy: 0.9212 - val_loss: 0.5998 - val_accuracy: 0.9176
# Epoch 91/250
# 390/390 - 26s - loss: 0.5736 - accuracy: 0.9217 - val_loss: 0.6058 - val_accuracy: 0.9137
# Epoch 92/250
# 390/390 - 26s - loss: 0.5700 - accuracy: 0.9213 - val_loss: 0.6115 - val_accuracy: 0.9082
# Epoch 93/250
# 390/390 - 26s - loss: 0.5693 - accuracy: 0.9209 - val_loss: 0.6200 - val_accuracy: 0.9083
# Epoch 94/250
# 390/390 - 26s - loss: 0.5590 - accuracy: 0.9237 - val_loss: 0.6195 - val_accuracy: 0.9101
# Epoch 95/250
# 390/390 - 26s - loss: 0.5687 - accuracy: 0.9189 - val_loss: 0.6129 - val_accuracy: 0.9076
# Epoch 96/250
# 390/390 - 27s - loss: 0.5630 - accuracy: 0.9212 - val_loss: 0.5995 - val_accuracy: 0.9144
# Epoch 97/250
# 390/390 - 26s - loss: 0.5639 - accuracy: 0.9195 - val_loss: 0.6249 - val_accuracy: 0.9067
# Epoch 98/250
# 390/390 - 26s - loss: 0.5600 - accuracy: 0.9193 - val_loss: 0.6292 - val_accuracy: 0.9066
# Epoch 99/250
# 390/390 - 26s - loss: 0.5554 - accuracy: 0.9216 - val_loss: 0.6158 - val_accuracy: 0.9081
# Epoch 100/250
# 390/390 - 26s - loss: 0.5554 - accuracy: 0.9228 - val_loss: 0.5875 - val_accuracy: 0.9169
# Epoch 101/250
# 390/390 - 26s - loss: 0.5184 - accuracy: 0.9329 - val_loss: 0.5641 - val_accuracy: 0.9233
# Epoch 102/250
# 390/390 - 26s - loss: 0.4996 - accuracy: 0.9388 - val_loss: 0.5705 - val_accuracy: 0.9184
# Epoch 103/250
# 390/390 - 26s - loss: 0.4905 - accuracy: 0.9395 - val_loss: 0.5588 - val_accuracy: 0.9243
# Epoch 104/250
# 390/390 - 26s - loss: 0.4785 - accuracy: 0.9430 - val_loss: 0.5755 - val_accuracy: 0.9193
# Epoch 105/250
# 390/390 - 26s - loss: 0.4743 - accuracy: 0.9429 - val_loss: 0.5736 - val_accuracy: 0.9204
# Epoch 106/250
# 390/390 - 26s - loss: 0.4708 - accuracy: 0.9434 - val_loss: 0.5613 - val_accuracy: 0.9213
# Epoch 107/250
# 390/390 - 26s - loss: 0.4719 - accuracy: 0.9423 - val_loss: 0.5486 - val_accuracy: 0.9248
# Epoch 108/250
# 390/390 - 27s - loss: 0.4629 - accuracy: 0.9438 - val_loss: 0.5434 - val_accuracy: 0.9257
# Epoch 109/250
# 390/390 - 26s - loss: 0.4590 - accuracy: 0.9428 - val_loss: 0.5469 - val_accuracy: 0.9246
# Epoch 110/250
# 390/390 - 26s - loss: 0.4557 - accuracy: 0.9444 - val_loss: 0.5507 - val_accuracy: 0.9190
# Epoch 111/250
# 390/390 - 26s - loss: 0.4520 - accuracy: 0.9452 - val_loss: 0.5536 - val_accuracy: 0.9200
# Epoch 112/250
# 390/390 - 26s - loss: 0.4479 - accuracy: 0.9450 - val_loss: 0.5490 - val_accuracy: 0.9180
# Epoch 113/250
# 390/390 - 26s - loss: 0.4433 - accuracy: 0.9464 - val_loss: 0.5446 - val_accuracy: 0.9215
# Epoch 114/250
# 390/390 - 26s - loss: 0.4445 - accuracy: 0.9445 - val_loss: 0.5392 - val_accuracy: 0.9210
# Epoch 115/250
# 390/390 - 26s - loss: 0.4376 - accuracy: 0.9461 - val_loss: 0.5436 - val_accuracy: 0.9186
# Epoch 116/250
# 390/390 - 26s - loss: 0.4401 - accuracy: 0.9452 - val_loss: 0.5540 - val_accuracy: 0.9160
# Epoch 117/250
# 390/390 - 26s - loss: 0.4356 - accuracy: 0.9446 - val_loss: 0.5618 - val_accuracy: 0.9178
# Epoch 118/250
# 390/390 - 26s - loss: 0.4304 - accuracy: 0.9462 - val_loss: 0.5437 - val_accuracy: 0.9195
# Epoch 119/250
# 390/390 - 26s - loss: 0.4339 - accuracy: 0.9443 - val_loss: 0.5260 - val_accuracy: 0.9251
# Epoch 120/250
# 390/390 - 26s - loss: 0.4282 - accuracy: 0.9463 - val_loss: 0.5263 - val_accuracy: 0.9219
# Epoch 121/250
# 390/390 - 26s - loss: 0.4043 - accuracy: 0.9535 - val_loss: 0.5117 - val_accuracy: 0.9301
# Epoch 122/250
# 390/390 - 26s - loss: 0.3936 - accuracy: 0.9569 - val_loss: 0.5052 - val_accuracy: 0.9273
# Epoch 123/250
# 390/390 - 26s - loss: 0.3878 - accuracy: 0.9570 - val_loss: 0.5066 - val_accuracy: 0.9298
# Epoch 124/250
# 390/390 - 26s - loss: 0.3810 - accuracy: 0.9602 - val_loss: 0.5056 - val_accuracy: 0.9292
# Epoch 125/250
# 390/390 - 26s - loss: 0.3828 - accuracy: 0.9576 - val_loss: 0.5202 - val_accuracy: 0.9258
# Epoch 126/250
# 390/390 - 26s - loss: 0.3726 - accuracy: 0.9604 - val_loss: 0.4994 - val_accuracy: 0.9303
# Epoch 127/250
# 390/390 - 26s - loss: 0.3727 - accuracy: 0.9611 - val_loss: 0.5014 - val_accuracy: 0.9306
# Epoch 128/250
# 390/390 - 26s - loss: 0.3655 - accuracy: 0.9623 - val_loss: 0.5106 - val_accuracy: 0.9307
# Epoch 129/250
# 390/390 - 26s - loss: 0.3654 - accuracy: 0.9616 - val_loss: 0.5169 - val_accuracy: 0.9254
# Epoch 130/250
# 390/390 - 26s - loss: 0.3628 - accuracy: 0.9616 - val_loss: 0.5182 - val_accuracy: 0.9251
# Epoch 131/250
# 390/390 - 26s - loss: 0.3609 - accuracy: 0.9614 - val_loss: 0.5104 - val_accuracy: 0.9264
# Epoch 132/250
# 390/390 - 26s - loss: 0.3595 - accuracy: 0.9619 - val_loss: 0.4954 - val_accuracy: 0.9284
# Epoch 133/250
# 390/390 - 26s - loss: 0.3530 - accuracy: 0.9632 - val_loss: 0.4977 - val_accuracy: 0.9281
# Epoch 134/250
# 390/390 - 26s - loss: 0.3585 - accuracy: 0.9617 - val_loss: 0.5156 - val_accuracy: 0.9241
# Epoch 135/250
# 390/390 - 26s - loss: 0.3520 - accuracy: 0.9625 - val_loss: 0.5022 - val_accuracy: 0.9276
# Epoch 136/250
# 390/390 - 26s - loss: 0.3534 - accuracy: 0.9618 - val_loss: 0.4924 - val_accuracy: 0.9288
# Epoch 137/250
# 390/390 - 26s - loss: 0.3485 - accuracy: 0.9632 - val_loss: 0.5041 - val_accuracy: 0.9247
# Epoch 138/250
# 390/390 - 26s - loss: 0.3467 - accuracy: 0.9628 - val_loss: 0.4947 - val_accuracy: 0.9284
# Epoch 139/250
# 390/390 - 26s - loss: 0.3463 - accuracy: 0.9638 - val_loss: 0.4943 - val_accuracy: 0.9270
# Epoch 140/250
# 390/390 - 26s - loss: 0.3447 - accuracy: 0.9630 - val_loss: 0.4913 - val_accuracy: 0.9277
# Epoch 141/250
# 390/390 - 26s - loss: 0.3319 - accuracy: 0.9667 - val_loss: 0.4913 - val_accuracy: 0.9276
# Epoch 142/250
# 390/390 - 26s - loss: 0.3289 - accuracy: 0.9680 - val_loss: 0.4881 - val_accuracy: 0.9295
# Epoch 143/250
# 390/390 - 27s - loss: 0.3213 - accuracy: 0.9707 - val_loss: 0.4879 - val_accuracy: 0.9303
# Epoch 144/250
# 390/390 - 26s - loss: 0.3150 - accuracy: 0.9708 - val_loss: 0.4886 - val_accuracy: 0.9294
# Epoch 145/250
# 390/390 - 26s - loss: 0.3138 - accuracy: 0.9721 - val_loss: 0.4938 - val_accuracy: 0.9299
# Epoch 146/250
# 390/390 - 26s - loss: 0.3162 - accuracy: 0.9703 - val_loss: 0.4898 - val_accuracy: 0.9316
# Epoch 147/250
# 390/390 - 26s - loss: 0.3146 - accuracy: 0.9714 - val_loss: 0.5001 - val_accuracy: 0.9282
# Epoch 148/250
# 390/390 - 26s - loss: 0.3108 - accuracy: 0.9721 - val_loss: 0.4894 - val_accuracy: 0.9322
# Epoch 149/250
# 390/390 - 26s - loss: 0.3089 - accuracy: 0.9723 - val_loss: 0.4810 - val_accuracy: 0.9318
# Epoch 150/250
# 390/390 - 26s - loss: 0.3067 - accuracy: 0.9725 - val_loss: 0.4972 - val_accuracy: 0.9298
# Epoch 151/250
# 390/390 - 26s - loss: 0.3043 - accuracy: 0.9723 - val_loss: 0.4882 - val_accuracy: 0.9304
# Epoch 152/250
# 390/390 - 26s - loss: 0.3067 - accuracy: 0.9714 - val_loss: 0.4777 - val_accuracy: 0.9328
# Epoch 153/250
# 390/390 - 26s - loss: 0.3010 - accuracy: 0.9736 - val_loss: 0.4857 - val_accuracy: 0.9317
# Epoch 154/250
# 390/390 - 26s - loss: 0.3036 - accuracy: 0.9730 - val_loss: 0.4848 - val_accuracy: 0.9307
# Epoch 155/250
# 390/390 - 27s - loss: 0.3007 - accuracy: 0.9731 - val_loss: 0.4871 - val_accuracy: 0.9300
# Epoch 156/250
# 390/390 - 26s - loss: 0.2970 - accuracy: 0.9731 - val_loss: 0.4800 - val_accuracy: 0.9323
# Epoch 157/250
# 390/390 - 26s - loss: 0.2964 - accuracy: 0.9736 - val_loss: 0.4855 - val_accuracy: 0.9326
# Epoch 158/250
# 390/390 - 27s - loss: 0.2958 - accuracy: 0.9738 - val_loss: 0.4941 - val_accuracy: 0.9318
# Epoch 159/250
# 390/390 - 27s - loss: 0.2952 - accuracy: 0.9729 - val_loss: 0.4822 - val_accuracy: 0.9307
# Epoch 160/250
# 390/390 - 27s - loss: 0.2944 - accuracy: 0.9736 - val_loss: 0.4718 - val_accuracy: 0.9327
# Epoch 161/250
# 390/390 - 26s - loss: 0.2874 - accuracy: 0.9752 - val_loss: 0.4705 - val_accuracy: 0.9321
# Epoch 162/250
# 390/390 - 26s - loss: 0.2873 - accuracy: 0.9754 - val_loss: 0.4776 - val_accuracy: 0.9318
# Epoch 163/250
# 390/390 - 27s - loss: 0.2839 - accuracy: 0.9760 - val_loss: 0.4724 - val_accuracy: 0.9319
# Epoch 164/250
# 390/390 - 27s - loss: 0.2800 - accuracy: 0.9781 - val_loss: 0.4772 - val_accuracy: 0.9313
# Epoch 165/250
# 390/390 - 26s - loss: 0.2800 - accuracy: 0.9778 - val_loss: 0.4773 - val_accuracy: 0.9324
# Epoch 166/250
# 390/390 - 27s - loss: 0.2791 - accuracy: 0.9773 - val_loss: 0.4779 - val_accuracy: 0.9304
# Epoch 167/250
# 390/390 - 27s - loss: 0.2747 - accuracy: 0.9789 - val_loss: 0.4770 - val_accuracy: 0.9321
# Epoch 168/250
# 390/390 - 27s - loss: 0.2774 - accuracy: 0.9788 - val_loss: 0.4670 - val_accuracy: 0.9335
# Epoch 169/250
# 390/390 - 27s - loss: 0.2759 - accuracy: 0.9786 - val_loss: 0.4734 - val_accuracy: 0.9313
# Epoch 170/250
# 390/390 - 27s - loss: 0.2766 - accuracy: 0.9776 - val_loss: 0.4761 - val_accuracy: 0.9317
# Epoch 171/250
# 390/390 - 27s - loss: 0.2736 - accuracy: 0.9784 - val_loss: 0.4716 - val_accuracy: 0.9314
# Epoch 172/250
# 390/390 - 27s - loss: 0.2743 - accuracy: 0.9783 - val_loss: 0.4743 - val_accuracy: 0.9323
# Epoch 173/250
# 390/390 - 27s - loss: 0.2720 - accuracy: 0.9791 - val_loss: 0.4694 - val_accuracy: 0.9342
# Epoch 174/250
# 390/390 - 27s - loss: 0.2730 - accuracy: 0.9776 - val_loss: 0.4698 - val_accuracy: 0.9320
# Epoch 175/250
# 390/390 - 27s - loss: 0.2702 - accuracy: 0.9787 - val_loss: 0.4621 - val_accuracy: 0.9345
# Epoch 176/250
# 390/390 - 27s - loss: 0.2693 - accuracy: 0.9789 - val_loss: 0.4663 - val_accuracy: 0.9337
# Epoch 177/250
# 390/390 - 27s - loss: 0.2651 - accuracy: 0.9810 - val_loss: 0.4681 - val_accuracy: 0.9326
# Epoch 178/250
# 390/390 - 27s - loss: 0.2685 - accuracy: 0.9793 - val_loss: 0.4657 - val_accuracy: 0.9314
# Epoch 179/250
# 390/390 - 27s - loss: 0.2689 - accuracy: 0.9789 - val_loss: 0.4675 - val_accuracy: 0.9327
# Epoch 180/250
# 390/390 - 26s - loss: 0.2635 - accuracy: 0.9806 - val_loss: 0.4701 - val_accuracy: 0.9326
# Epoch 181/250
# 390/390 - 27s - loss: 0.2628 - accuracy: 0.9801 - val_loss: 0.4684 - val_accuracy: 0.9317
# Epoch 182/250
# 390/390 - 26s - loss: 0.2627 - accuracy: 0.9807 - val_loss: 0.4683 - val_accuracy: 0.9338
# Epoch 183/250
# 390/390 - 26s - loss: 0.2633 - accuracy: 0.9801 - val_loss: 0.4702 - val_accuracy: 0.9344
# Epoch 184/250
# 390/390 - 26s - loss: 0.2600 - accuracy: 0.9819 - val_loss: 0.4662 - val_accuracy: 0.9342
# Epoch 185/250
# 390/390 - 26s - loss: 0.2602 - accuracy: 0.9808 - val_loss: 0.4679 - val_accuracy: 0.9334
# Epoch 186/250
# 390/390 - 26s - loss: 0.2596 - accuracy: 0.9816 - val_loss: 0.4669 - val_accuracy: 0.9345
# Epoch 187/250
# 390/390 - 26s - loss: 0.2600 - accuracy: 0.9806 - val_loss: 0.4688 - val_accuracy: 0.9335
# Epoch 188/250
# 390/390 - 26s - loss: 0.2619 - accuracy: 0.9798 - val_loss: 0.4643 - val_accuracy: 0.9342
# Epoch 189/250
# 390/390 - 26s - loss: 0.2580 - accuracy: 0.9814 - val_loss: 0.4667 - val_accuracy: 0.9324
# Epoch 190/250
# 390/390 - 27s - loss: 0.2565 - accuracy: 0.9822 - val_loss: 0.4676 - val_accuracy: 0.9330
# Epoch 191/250
# 390/390 - 26s - loss: 0.2564 - accuracy: 0.9821 - val_loss: 0.4701 - val_accuracy: 0.9328
# Epoch 192/250
# 390/390 - 26s - loss: 0.2578 - accuracy: 0.9816 - val_loss: 0.4690 - val_accuracy: 0.9331
# Epoch 193/250
# 390/390 - 26s - loss: 0.2585 - accuracy: 0.9815 - val_loss: 0.4714 - val_accuracy: 0.9323
# Epoch 194/250
# 390/390 - 26s - loss: 0.2578 - accuracy: 0.9811 - val_loss: 0.4688 - val_accuracy: 0.9332
# Epoch 195/250
# 390/390 - 26s - loss: 0.2552 - accuracy: 0.9825 - val_loss: 0.4637 - val_accuracy: 0.9334
# Epoch 196/250
# 390/390 - 26s - loss: 0.2555 - accuracy: 0.9816 - val_loss: 0.4640 - val_accuracy: 0.9335
# Epoch 197/250
# 390/390 - 26s - loss: 0.2547 - accuracy: 0.9820 - val_loss: 0.4664 - val_accuracy: 0.9328
# Epoch 198/250
# 390/390 - 26s - loss: 0.2532 - accuracy: 0.9825 - val_loss: 0.4669 - val_accuracy: 0.9337
# Epoch 199/250
# 390/390 - 26s - loss: 0.2518 - accuracy: 0.9824 - val_loss: 0.4687 - val_accuracy: 0.9327
# Epoch 200/250
# 390/390 - 26s - loss: 0.2547 - accuracy: 0.9818 - val_loss: 0.4687 - val_accuracy: 0.9314
# Epoch 201/250
# 390/390 - 26s - loss: 0.2516 - accuracy: 0.9823 - val_loss: 0.4683 - val_accuracy: 0.9321
# Epoch 202/250
# 390/390 - 27s - loss: 0.2514 - accuracy: 0.9823 - val_loss: 0.4660 - val_accuracy: 0.9328
# Epoch 203/250
# 390/390 - 26s - loss: 0.2509 - accuracy: 0.9824 - val_loss: 0.4665 - val_accuracy: 0.9328
# Epoch 204/250
# 390/390 - 26s - loss: 0.2473 - accuracy: 0.9836 - val_loss: 0.4653 - val_accuracy: 0.9338
# Epoch 205/250
# 390/390 - 26s - loss: 0.2525 - accuracy: 0.9822 - val_loss: 0.4671 - val_accuracy: 0.9340
# Epoch 206/250
# 390/390 - 26s - loss: 0.2515 - accuracy: 0.9822 - val_loss: 0.4660 - val_accuracy: 0.9340
# Epoch 207/250
# 390/390 - 26s - loss: 0.2502 - accuracy: 0.9835 - val_loss: 0.4630 - val_accuracy: 0.9338
# Epoch 208/250
# 390/390 - 26s - loss: 0.2530 - accuracy: 0.9821 - val_loss: 0.4672 - val_accuracy: 0.9338
# Epoch 209/250
# 390/390 - 27s - loss: 0.2496 - accuracy: 0.9831 - val_loss: 0.4631 - val_accuracy: 0.9337
# Epoch 210/250
# 390/390 - 26s - loss: 0.2498 - accuracy: 0.9828 - val_loss: 0.4646 - val_accuracy: 0.9340
# Epoch 211/250
# 390/390 - 26s - loss: 0.2486 - accuracy: 0.9835 - val_loss: 0.4658 - val_accuracy: 0.9337
# Epoch 212/250
# 390/390 - 26s - loss: 0.2487 - accuracy: 0.9831 - val_loss: 0.4656 - val_accuracy: 0.9337
# Epoch 213/250
# 390/390 - 26s - loss: 0.2498 - accuracy: 0.9827 - val_loss: 0.4644 - val_accuracy: 0.9343
# Epoch 214/250
# 390/390 - 26s - loss: 0.2473 - accuracy: 0.9837 - val_loss: 0.4634 - val_accuracy: 0.9348
# Epoch 215/250
# 390/390 - 26s - loss: 0.2495 - accuracy: 0.9829 - val_loss: 0.4661 - val_accuracy: 0.9333
# Epoch 216/250
# 390/390 - 26s - loss: 0.2476 - accuracy: 0.9836 - val_loss: 0.4654 - val_accuracy: 0.9340
# Epoch 217/250
# 390/390 - 26s - loss: 0.2462 - accuracy: 0.9834 - val_loss: 0.4623 - val_accuracy: 0.9346
# Epoch 218/250
# 390/390 - 26s - loss: 0.2473 - accuracy: 0.9834 - val_loss: 0.4623 - val_accuracy: 0.9350
# Epoch 219/250
# 390/390 - 26s - loss: 0.2497 - accuracy: 0.9824 - val_loss: 0.4641 - val_accuracy: 0.9339
# Epoch 220/250
# 390/390 - 27s - loss: 0.2490 - accuracy: 0.9827 - val_loss: 0.4621 - val_accuracy: 0.9349
# Epoch 221/250
# 390/390 - 26s - loss: 0.2480 - accuracy: 0.9830 - val_loss: 0.4631 - val_accuracy: 0.9342
# Epoch 222/250
# 390/390 - 26s - loss: 0.2477 - accuracy: 0.9836 - val_loss: 0.4622 - val_accuracy: 0.9356
# Epoch 223/250
# 390/390 - 26s - loss: 0.2471 - accuracy: 0.9845 - val_loss: 0.4635 - val_accuracy: 0.9335
# Epoch 224/250
# 390/390 - 27s - loss: 0.2438 - accuracy: 0.9846 - val_loss: 0.4642 - val_accuracy: 0.9335
# Epoch 225/250
# 390/390 - 27s - loss: 0.2468 - accuracy: 0.9833 - val_loss: 0.4627 - val_accuracy: 0.9336
# Epoch 226/250
# 390/390 - 26s - loss: 0.2454 - accuracy: 0.9841 - val_loss: 0.4635 - val_accuracy: 0.9341
# Epoch 227/250
# 390/390 - 26s - loss: 0.2458 - accuracy: 0.9838 - val_loss: 0.4639 - val_accuracy: 0.9337
# Epoch 228/250
# 390/390 - 26s - loss: 0.2436 - accuracy: 0.9844 - val_loss: 0.4631 - val_accuracy: 0.9347
# Epoch 229/250
# 390/390 - 26s - loss: 0.2481 - accuracy: 0.9830 - val_loss: 0.4639 - val_accuracy: 0.9348
# Epoch 230/250
# 390/390 - 26s - loss: 0.2435 - accuracy: 0.9847 - val_loss: 0.4621 - val_accuracy: 0.9345
# Epoch 231/250
# 390/390 - 26s - loss: 0.2448 - accuracy: 0.9841 - val_loss: 0.4637 - val_accuracy: 0.9346
# Epoch 232/250
# 390/390 - 26s - loss: 0.2428 - accuracy: 0.9853 - val_loss: 0.4657 - val_accuracy: 0.9344
# Epoch 233/250
# 390/390 - 26s - loss: 0.2454 - accuracy: 0.9833 - val_loss: 0.4654 - val_accuracy: 0.9341
# Epoch 234/250
# 390/390 - 26s - loss: 0.2431 - accuracy: 0.9843 - val_loss: 0.4634 - val_accuracy: 0.9342
# Epoch 235/250
# 390/390 - 26s - loss: 0.2431 - accuracy: 0.9839 - val_loss: 0.4620 - val_accuracy: 0.9339
# Epoch 236/250
# 390/390 - 26s - loss: 0.2447 - accuracy: 0.9841 - val_loss: 0.4623 - val_accuracy: 0.9334
# Epoch 237/250
# 390/390 - 26s - loss: 0.2431 - accuracy: 0.9844 - val_loss: 0.4616 - val_accuracy: 0.9347
# Epoch 238/250
# 390/390 - 26s - loss: 0.2411 - accuracy: 0.9847 - val_loss: 0.4626 - val_accuracy: 0.9346
# Epoch 239/250
# 390/390 - 26s - loss: 0.2461 - accuracy: 0.9838 - val_loss: 0.4632 - val_accuracy: 0.9337
# Epoch 240/250
# 390/390 - 26s - loss: 0.2434 - accuracy: 0.9845 - val_loss: 0.4619 - val_accuracy: 0.9339
# Epoch 241/250
# 390/390 - 26s - loss: 0.2442 - accuracy: 0.9840 - val_loss: 0.4607 - val_accuracy: 0.9340
# Epoch 242/250
# 390/390 - 26s - loss: 0.2439 - accuracy: 0.9842 - val_loss: 0.4626 - val_accuracy: 0.9335
# Epoch 243/250
# 390/390 - 26s - loss: 0.2426 - accuracy: 0.9841 - val_loss: 0.4615 - val_accuracy: 0.9345
# Epoch 244/250
# 390/390 - 26s - loss: 0.2434 - accuracy: 0.9845 - val_loss: 0.4617 - val_accuracy: 0.9340
# Epoch 245/250
# 390/390 - 26s - loss: 0.2424 - accuracy: 0.9845 - val_loss: 0.4620 - val_accuracy: 0.9344
# Epoch 246/250
# 390/390 - 26s - loss: 0.2453 - accuracy: 0.9840 - val_loss: 0.4637 - val_accuracy: 0.9338
# Epoch 247/250
# 390/390 - 26s - loss: 0.2435 - accuracy: 0.9842 - val_loss: 0.4621 - val_accuracy: 0.9346
# Epoch 248/250
# 390/390 - 26s - loss: 0.2438 - accuracy: 0.9839 - val_loss: 0.4629 - val_accuracy: 0.9339
# Epoch 249/250
# 390/390 - 26s - loss: 0.2427 - accuracy: 0.9837 - val_loss: 0.4618 - val_accuracy: 0.9348
# Epoch 250/250
# 390/390 - 26s - loss: 0.2428 - accuracy: 0.9850 - val_loss: 0.4617 - val_accuracy: 0.9341
# the validation 0/1 loss is:  0.0659
